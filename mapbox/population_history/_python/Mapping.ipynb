# %% [markdown]
# ImportError: The descartes package is required for plotting polygons in geopandas<br>
# -> conda install descartes

# %%
import geopandas as gpd

gdf = gpd.read_file("./shapefile/jpc_city2021/city2021_ok.shp",encoding='utf-8')

gdf2 = gdf[(gdf["区分"] == 138) | (gdf["区分"] == 23)]

print(gdf2)
# Out:
#      NEW_ID  ken   gun name1 name2   区分   地域  都道府  都市名   タイプ     市区町  \
# 0     01100  北海道  None   札幌市   中央区  138  北海道  北海道   札幌  政令指定  011002
# 1     01202  北海道  None   函館市  None  138  北海道  北海道   函館   その他  012025
# 2     01204  北海道  None   旭川市  None  138  北海道  北海道   旭川   その他  012041
# 3     01206  北海道  None   釧路市  None  138  北海道  北海道   釧路   その他  012068
# 4     01213  北海道  None  苫小牧市  None  138  北海道  北海道  苫小牧   その他  012131
# ...     ...  ...   ...   ...   ...  ...  ...  ...  ...   ...     ...
# 1171  27215  大阪府  None  寝屋川市  None  138   近畿  大阪府  寝屋川    新規  272159
# 1175  27219  大阪府  None   和泉市  None  138   近畿  大阪府   和泉    新規  272191
# 1198  28203  兵庫県  None   明石市  None  138   近畿  兵庫県   明石    新規  282031
# 1203  28210  兵庫県  None  加古川市  None  138   近畿  兵庫県  加古川    新規  282103
# 1206  28214  兵庫県  None   宝塚市  None  138   近畿  兵庫県   宝塚    新規  282146
#
#                                                geometry
# 0     POLYGON ((141.40864 43.18412, 141.40823 43.183...
# ...

# %%
gdf2.plot(figsize=(20,16))
# Out:
# <AxesSubplot:>
